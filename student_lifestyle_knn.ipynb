# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd

from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('student_lifestyle_dataset.csv')

# %%
features = ['Study_Hours_Per_Day', 'Extracurricular_Hours_Per_Day', 'Sleep_Hours_Per_Day', 'Social_Hours_Per_Day', 'Physical_Activity_Hours_Per_Day', 'Stress_Level', 'Gender']

# %%
df = df.replace({'Low' : 0, 'Moderate' : 1, 'High' : 2, 'Male' : 0, 'Female' : 1})

# %%
x = df[features]
y = df['Grades']

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.3, random_state = 0)
model = KNeighborsRegressor(n_neighbors=45)

# %%
model.fit(train_x, train_y)
# Out:
# KNeighborsRegressor(n_neighbors=45)

# %%
predictions = model.predict(test_x)

# %%
model.score(test_x, test_y)
# Out:
# 0.49680430074492277

# %%
mean_squared_error(test_y, predictions)
# Out:
# 0.2634319004115227

# %%
mean_absolute_error(test_y, predictions)
# Out:
# 0.41656592592592595

# %%
gs = GridSearchCV(KNeighborsRegressor(), {'n_neighbors' : range(1, 90)}, scoring = 'r2')

# %%
gs.fit(train_x, train_y)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(1, 90)}, scoring='r2')

# %%
model2 = KNeighborsRegressor(n_neighbors=28)

# %%
model2.fit(train_x, train_y)
# Out:
# KNeighborsRegressor(n_neighbors=28)

# %%
predictions2 = model2.predict(test_x)

# %%
model2.score(test_x, test_y)
# Out:
# 0.4960566987115179

# %%
mean_squared_error(test_y, predictions2)
# Out:
# 0.2638232833758503

# %%
mean_absolute_error(test_y, predictions2)
# Out:
# 0.41612083333333333
